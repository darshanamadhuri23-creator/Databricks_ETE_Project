# %%
df = spark.read.table("databricks_catalog.bronze.region")

# %%
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@etedatabricksa.dfs.core.windows.net/region")

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@etedatabricksa.dfs.core.windows.net/products")

df.display()

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_catalog.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@etedatabricksa.dfs.core.windows.net/region'
