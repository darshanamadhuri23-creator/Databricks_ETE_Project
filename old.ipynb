# %%
df = spark.read.format("parquet").load("abfss://source@etedatabricksa.dfs.core.windows.net/Orders")
df.display()

# %%
df = spark.readStream.format("cloudFiles")\
            .option("cloudFiles.format","parquet")\
            .option("cloudFiles.schemaLocation","abfss://bronze@etedatabricksa.dfs.core.windows.net/checkpoint_Orders")\
            .schema(schema)\
             .load("abfss://source@etedatabricksa.dfs.core.windows.net/Orders")

# %%
df.writeStream.format("parquet")\
.outputMode("append")\
            .option("checkpointLocation", "abfss://bronze@etedatabricksa.dfs.core.windows.net/checkpoint_Orders")\
            .option("path","abfss://bronze@etedatabricksa.dfs.core.windows.net/Orders")\
            .trigger(once=True)\
            .start()

# %%
df = spark.read.format("parquet").load("abfss://bronze@etedatabricksa.dfs.core.windows.net/Orders")
df.display()
